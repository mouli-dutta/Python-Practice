# %%
import pandas as pd

# %% [markdown]
# ## 1. Read a CSV file and filter rows based on a specific column

# %%
# Read CSV file
file_path = 'input.csv'

try:    
    df = pd.read_csv(file_path)

except FileNotFoundError:
    print('File not found')

# %%
df.dtypes
# Out:
# timestamp      object
# id              int64
# name           object
# age           float64
# salary        float64
# department     object
# location       object
# status         object
# score         float64
# remarks        object
# dtype: object

# %%
df.head()
# Out:
#              timestamp   id   name   age   salary department     location
# 0  2024-02-23 10:15:30  101   John  25.0  50000.0      Sales     New York  \
# 1  2024-02-23 10:16:45  102   Anna  30.0  60000.0         HR      Chicago
# 2  2024-02-23 10:17:00  103  James   NaN  55000.0         IT  Los Angeles
# 3  2024-02-23 10:17:00  103  James   NaN  55000.0         IT  Los Angeles
# 4  2024-02-23 10:18:20  104  Maria  28.0  52000.0  Marketing          NaN
#
#      status  score    remarks
# 0    Active   85.0       Good
# 1    Active   90.0  Excellent
# 2  Inactive    NaN        NaN
# 3  Inactive    NaN        NaN
# 4    Active   75.0    Average

# %%
# target column name
col_name = 'score'

# keep only the rows where column_name is not null
filtered_df = df[df[col_name].notna()]
    
filtered_df
# Out:
#               timestamp   id     name   age   salary department     location
# 0   2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1   2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 4   2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing          NaN
# 5   2024-02-23 10:19:10  105  Michael  35.0      NaN    Finance        Miami
# 6   2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 8   2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 9   2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 10  2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status  score    remarks
# 0     Active   85.0       Good
# 1     Active   90.0  Excellent
# 4     Active   75.0    Average
# 5   Inactive   88.0       Good
# 6     Active   95.0  Excellent
# 8     Active   92.0  Very Good
# 9     Active   92.0  Very Good
# 10  Inactive   80.0       Good

# %% [markdown]
# ## 2. Merge two dataframes using a common column

# %%
# Example DataFrame

df1 = pd.DataFrame(
    {
        'id' : [1, 2, 3],
        'name' : ['Alice', 'Bob', 'Suzy']
    }
)

df2 = pd.DataFrame(
    {
        'id' : [1, 2, 4],
        'age' : [25, 20, 28]
    }
)

# %% [markdown]
# ### Joins in Pandas

# %%
# INNER JOIN : Keeps only matching rows
inner_join = pd.merge(df1, df2, on='id', how='inner')

# LEFT JOIN : Keeps all rows from df1, fills unmatched with NaN
left_join = pd.merge(df1, df2, on='id', how='left')

# RIGHT JOIN : Keeps all rows from df2, fills unmatched with NaN
right_join = pd.merge(df1, df2, on='id', how='right')

# OUTER JOIN : Keeps all rows from both, fills unmatched with NaN
outer_join = pd.merge(df1, df2, on='id', how='outer')


# print results
print("Inner Join:\n", inner_join)
print("\nLeft Join:\n", left_join)
print("\nRight Join:\n", right_join)
print("\nOuter Join:\n", outer_join)
# Out:
# Inner Join:
#     id   name  age
# 0   1  Alice   25
# 1   2    Bob   20
#
# Left Join:
#     id   name   age
# 0   1  Alice  25.0
# 1   2    Bob  20.0
# 2   3   Suzy   NaN
#
# Right Join:
#     id   name  age
# 0   1  Alice   25
# 1   2    Bob   20
# 2   4    NaN   28
#
# Outer Join:
#     id   name   age
# 0   1  Alice  25.0
# 1   2    Bob  20.0
# 2   3   Suzy   NaN
# 3   4    NaN  28.0

# %% [markdown]
# ## 3. Write a DataFrame to a CSV file without the index

# %%
df1.to_csv('Output.csv', index=False)

# %% [markdown]
# ## 4. Handle missing data by replacing NaN values

# %% [markdown]
# ### 1. Replace NaN with 0 or string

# %%
df.fillna(0)
# Out:
#               timestamp   id     name   age   salary department     location
# 0   2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1   2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2   2024-02-23 10:17:00  103    James   0.0  55000.0         IT  Los Angeles
# 3   2024-02-23 10:17:00  103    James   0.0  55000.0         IT  Los Angeles
# 4   2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing            0
# 5   2024-02-23 10:19:10  105  Michael  35.0      0.0    Finance        Miami
# 6   2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 7   2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 8   2024-02-23 10:22:10  108     Emma   0.0  65000.0      Sales  Los Angeles
# 9   2024-02-23 10:22:10  108     Emma   0.0  65000.0      Sales  Los Angeles
# 10  2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status  score    remarks
# 0     Active   85.0       Good
# 1     Active   90.0  Excellent
# 2   Inactive    0.0          0
# 3   Inactive    0.0          0
# 4     Active   75.0    Average
# 5   Inactive   88.0       Good
# 6     Active   95.0  Excellent
# 7     Active    0.0          0
# 8     Active   92.0  Very Good
# 9     Active   92.0  Very Good
# 10  Inactive   80.0       Good

# %%
df.fillna('Missing')
# Out:
#               timestamp   id     name      age   salary department
# 0   2024-02-23 10:15:30  101     John     25.0  50000.0      Sales  \
# 1   2024-02-23 10:16:45  102     Anna     30.0  60000.0         HR
# 2   2024-02-23 10:17:00  103    James  Missing  55000.0         IT
# 3   2024-02-23 10:17:00  103    James  Missing  55000.0         IT
# 4   2024-02-23 10:18:20  104    Maria     28.0  52000.0  Marketing
# 5   2024-02-23 10:19:10  105  Michael     35.0  Missing    Finance
# 6   2024-02-23 10:20:05  106   Sophia     40.0  70000.0         HR
# 7   2024-02-23 10:21:30  107     Liam     27.0  48000.0         IT
# 8   2024-02-23 10:22:10  108     Emma  Missing  65000.0      Sales
# 9   2024-02-23 10:22:10  108     Emma  Missing  65000.0      Sales
# 10  2024-02-23 10:23:50  109  William     32.0  58000.0  Marketing
#
#        location    status    score    remarks
# 0      New York    Active     85.0       Good
# 1       Chicago    Active     90.0  Excellent
# 2   Los Angeles  Inactive  Missing    Missing
# 3   Los Angeles  Inactive  Missing    Missing
# 4       Missing    Active     75.0    Average
# 5         Miami  Inactive     88.0       Good
# 6       Chicago    Active     95.0  Excellent
# 7      New York    Active  Missing    Missing
# 8   Los Angeles    Active     92.0  Very Good
# 9   Los Angeles    Active     92.0  Very Good
# 10      Chicago  Inactive     80.0       Good

# %%
col = 'score'

# %% [markdown]
# ### 2. Fill NaN with Column Mean, Median or Mode

# %% [markdown]
# #### a. Fill NaN with Mean

# %%
df_copy = df.copy()
df_copy[col] = df_copy[col].fillna(df_copy[col].mean())

df_copy
# Out:
#               timestamp   id     name   age   salary department     location
# 0   2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1   2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2   2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 3   2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 4   2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing          NaN
# 5   2024-02-23 10:19:10  105  Michael  35.0      NaN    Finance        Miami
# 6   2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 7   2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 8   2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 9   2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 10  2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status   score    remarks
# 0     Active  85.000       Good
# 1     Active  90.000  Excellent
# 2   Inactive  87.125        NaN
# 3   Inactive  87.125        NaN
# 4     Active  75.000    Average
# 5   Inactive  88.000       Good
# 6     Active  95.000  Excellent
# 7     Active  87.125        NaN
# 8     Active  92.000  Very Good
# 9     Active  92.000  Very Good
# 10  Inactive  80.000       Good

# %% [markdown]
# #### b. Fill NaN with Median

# %%
df_copy = df.copy()
df_copy[col] = df_copy[col].fillna(df_copy[col].median())

df_copy
# Out:
#               timestamp   id     name   age   salary department     location
# 0   2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1   2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2   2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 3   2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 4   2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing          NaN
# 5   2024-02-23 10:19:10  105  Michael  35.0      NaN    Finance        Miami
# 6   2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 7   2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 8   2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 9   2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 10  2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status  score    remarks
# 0     Active   85.0       Good
# 1     Active   90.0  Excellent
# 2   Inactive   89.0        NaN
# 3   Inactive   89.0        NaN
# 4     Active   75.0    Average
# 5   Inactive   88.0       Good
# 6     Active   95.0  Excellent
# 7     Active   89.0        NaN
# 8     Active   92.0  Very Good
# 9     Active   92.0  Very Good
# 10  Inactive   80.0       Good

# %% [markdown]
# #### c. Fill NaN with Mode

# %%
df_copy = df.copy()
df_copy[col] = df_copy[col].fillna(df_copy[col].mode()[0])

df_copy
# Out:
#               timestamp   id     name   age   salary department     location
# 0   2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1   2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2   2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 3   2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 4   2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing          NaN
# 5   2024-02-23 10:19:10  105  Michael  35.0      NaN    Finance        Miami
# 6   2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 7   2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 8   2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 9   2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 10  2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status  score    remarks
# 0     Active   85.0       Good
# 1     Active   90.0  Excellent
# 2   Inactive   92.0        NaN
# 3   Inactive   92.0        NaN
# 4     Active   75.0    Average
# 5   Inactive   88.0       Good
# 6     Active   95.0  Excellent
# 7     Active   92.0        NaN
# 8     Active   92.0  Very Good
# 9     Active   92.0  Very Good
# 10  Inactive   80.0       Good

# %% [markdown]
# ### 3. Fill using Forward/Backward fill

# %%
df.fillna(method='ffill') # forward fill (copy previous value)
# Out:
#               timestamp   id     name   age   salary department     location
# 0   2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1   2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2   2024-02-23 10:17:00  103    James  30.0  55000.0         IT  Los Angeles
# 3   2024-02-23 10:17:00  103    James  30.0  55000.0         IT  Los Angeles
# 4   2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing  Los Angeles
# 5   2024-02-23 10:19:10  105  Michael  35.0  52000.0    Finance        Miami
# 6   2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 7   2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 8   2024-02-23 10:22:10  108     Emma  27.0  65000.0      Sales  Los Angeles
# 9   2024-02-23 10:22:10  108     Emma  27.0  65000.0      Sales  Los Angeles
# 10  2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status  score    remarks
# 0     Active   85.0       Good
# 1     Active   90.0  Excellent
# 2   Inactive   90.0  Excellent
# 3   Inactive   90.0  Excellent
# 4     Active   75.0    Average
# 5   Inactive   88.0       Good
# 6     Active   95.0  Excellent
# 7     Active   95.0  Excellent
# 8     Active   92.0  Very Good
# 9     Active   92.0  Very Good
# 10  Inactive   80.0       Good

# %%
df.fillna(method='bfill') # backward fill (copy next value)
# Out:
#               timestamp   id     name   age   salary department     location
# 0   2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1   2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2   2024-02-23 10:17:00  103    James  28.0  55000.0         IT  Los Angeles
# 3   2024-02-23 10:17:00  103    James  28.0  55000.0         IT  Los Angeles
# 4   2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing        Miami
# 5   2024-02-23 10:19:10  105  Michael  35.0  70000.0    Finance        Miami
# 6   2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 7   2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 8   2024-02-23 10:22:10  108     Emma  32.0  65000.0      Sales  Los Angeles
# 9   2024-02-23 10:22:10  108     Emma  32.0  65000.0      Sales  Los Angeles
# 10  2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status  score    remarks
# 0     Active   85.0       Good
# 1     Active   90.0  Excellent
# 2   Inactive   75.0    Average
# 3   Inactive   75.0    Average
# 4     Active   75.0    Average
# 5   Inactive   88.0       Good
# 6     Active   95.0  Excellent
# 7     Active   92.0  Very Good
# 8     Active   92.0  Very Good
# 9     Active   92.0  Very Good
# 10  Inactive   80.0       Good

# %% [markdown]
# ### 4. Fill NaN with Interpolation

# %%
df.interpolate() # Linear interpolation
df.interpolate(method='polynomial', order=2) # Polynomial interpolation
# Out:
#               timestamp   id     name        age        salary department
# 0   2024-02-23 10:15:30  101     John  25.000000  50000.000000      Sales  \
# 1   2024-02-23 10:16:45  102     Anna  30.000000  60000.000000         HR
# 2   2024-02-23 10:17:00  103    James  30.059128  55000.000000         IT
# 3   2024-02-23 10:17:00  103    James  26.582411  55000.000000         IT
# 4   2024-02-23 10:18:20  104    Maria  28.000000  52000.000000  Marketing
# 5   2024-02-23 10:19:10  105  Michael  35.000000  65697.836167    Finance
# 6   2024-02-23 10:20:05  106   Sophia  40.000000  70000.000000         HR
# 7   2024-02-23 10:21:30  107     Liam  27.000000  48000.000000         IT
# 8   2024-02-23 10:22:10  108     Emma  19.132240  65000.000000      Sales
# 9   2024-02-23 10:22:10  108     Emma  20.798907  65000.000000      Sales
# 10  2024-02-23 10:23:50  109  William  32.000000  58000.000000  Marketing
#
#        location    status      score    remarks
# 0      New York    Active  85.000000       Good
# 1       Chicago    Active  90.000000  Excellent
# 2   Los Angeles  Inactive  85.341367        NaN
# 3   Los Angeles  Inactive  74.129855        NaN
# 4           NaN    Active  75.000000    Average
# 5         Miami  Inactive  88.000000       Good
# 6       Chicago    Active  95.000000  Excellent
# 7      New York    Active  94.235327        NaN
# 8   Los Angeles    Active  92.000000  Very Good
# 9   Los Angeles    Active  92.000000  Very Good
# 10      Chicago  Inactive  80.000000       Good

# %% [markdown]
# ### 5. Fill NaN with different values for each column

# %%
df.fillna(
    {
        'score' : 0,
        'remarks' : 'Missing',
        'age' : df['age'].mean()
    }
)

df[['age', 'score', 'remarks']]
# Out:
#      age  score    remarks
# 0   25.0   85.0       Good
# 1   30.0   90.0  Excellent
# 2    NaN    NaN        NaN
# 3    NaN    NaN        NaN
# 4   28.0   75.0    Average
# 5   35.0   88.0       Good
# 6   40.0   95.0  Excellent
# 7   27.0    NaN        NaN
# 8    NaN   92.0  Very Good
# 9    NaN   92.0  Very Good
# 10  32.0   80.0       Good

# %% [markdown]
# ### 6. Fill NaN using a function

# %%
df_copy = df.copy()
df_copy['age'] = df_copy['age'].apply(lambda x : df['age'].median() if pd.isna(x) else x)
df_copy[['id', 'name', 'age', 'salary']]
# Out:
#      id     name   age   salary
# 0   101     John  25.0  50000.0
# 1   102     Anna  30.0  60000.0
# 2   103    James  30.0  55000.0
# 3   103    James  30.0  55000.0
# 4   104    Maria  28.0  52000.0
# 5   105  Michael  35.0      NaN
# 6   106   Sophia  40.0  70000.0
# 7   107     Liam  27.0  48000.0
# 8   108     Emma  30.0  65000.0
# 9   108     Emma  30.0  65000.0
# 10  109  William  32.0  58000.0

# %% [markdown]
# ### 7. Replace NaN in specific rows

# %%
doc = """
        1. df[col].isna()
                a. Checks which values in column col are NaN (Missing).
                b. Returns a Boolean Series (True for NaN, False otherwise).

        2. df.loc[df[col].isna(), col]
                a. df.loc[] selects rows where the condition is True (i.e., where column in NaN).
                b. Targets only the col column

        3. = 'custom value'
                a. assigns custom value to all selected NaN entries in col
            
"""



df_copy = df.copy()
df_copy.loc[df_copy['remarks'].isna(), 'remarks'] = 'Outstanding'
df_copy[['remarks']]
# Out:
#         remarks
# 0          Good
# 1     Excellent
# 2   Outstanding
# 3   Outstanding
# 4       Average
# 5          Good
# 6     Excellent
# 7   Outstanding
# 8     Very Good
# 9     Very Good
# 10         Good

# %% [markdown]
# ## 5. Convert a DataFrame column string to datetime format

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

print(df.dtypes) # check data type
# Out:
# timestamp     datetime64[ns]
# id                     int64
# name                  object
# age                  float64
# salary               float64
# department            object
# location              object
# status                object
# score                float64
# remarks               object
# dtype: object

# %% [markdown]
# ## 6. Handling Duplicates

# %% [markdown]
# ### 1. Remove duplicate rows

# %%
df = df.drop_duplicates()
doc = """
    1. Remove duplicate rows, keeping the first occurrence.
    2. Equivalent to df.drop_duplicates(keep='first')
"""
df
# Out:
#              timestamp   id     name   age   salary department     location
# 0  2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1  2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2  2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 4  2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing          NaN
# 5  2024-02-23 10:19:10  105  Michael  35.0      NaN    Finance        Miami
# 6  2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 7  2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 8  2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 10 2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status  score    remarks
# 0     Active   85.0       Good
# 1     Active   90.0  Excellent
# 2   Inactive    NaN        NaN
# 4     Active   75.0    Average
# 5   Inactive   88.0       Good
# 6     Active   95.0  Excellent
# 7     Active    NaN        NaN
# 8     Active   92.0  Very Good
# 10  Inactive   80.0       Good

# %% [markdown]
# ### 2. Remove duplicate rows based on specific column(s)

# %%
# Removes duplicate values based on a specific column (col_name).
df_copy = df.copy()
df_copy = df_copy.drop_duplicates(subset=['remarks'])
df_copy
# Out:
#             timestamp   id   name   age   salary department     location
# 0 2024-02-23 10:15:30  101   John  25.0  50000.0      Sales     New York  \
# 1 2024-02-23 10:16:45  102   Anna  30.0  60000.0         HR      Chicago
# 2 2024-02-23 10:17:00  103  James   NaN  55000.0         IT  Los Angeles
# 4 2024-02-23 10:18:20  104  Maria  28.0  52000.0  Marketing          NaN
# 8 2024-02-23 10:22:10  108   Emma   NaN  65000.0      Sales  Los Angeles
#
#      status  score    remarks
# 0    Active   85.0       Good
# 1    Active   90.0  Excellent
# 2  Inactive    NaN        NaN
# 4    Active   75.0    Average
# 8    Active   92.0  Very Good

# %%
# Can specify multiple columns:
df_copy = df_copy.drop_duplicates(subset=['status', 'location'])
df_copy
# Out:
#             timestamp   id   name   age   salary department     location
# 0 2024-02-23 10:15:30  101   John  25.0  50000.0      Sales     New York  \
# 1 2024-02-23 10:16:45  102   Anna  30.0  60000.0         HR      Chicago
# 2 2024-02-23 10:17:00  103  James   NaN  55000.0         IT  Los Angeles
# 4 2024-02-23 10:18:20  104  Maria  28.0  52000.0  Marketing          NaN
# 8 2024-02-23 10:22:10  108   Emma   NaN  65000.0      Sales  Los Angeles
#
#      status  score    remarks
# 0    Active   85.0       Good
# 1    Active   90.0  Excellent
# 2  Inactive    NaN        NaN
# 4    Active   75.0    Average
# 8    Active   92.0  Very Good

# %% [markdown]
# ### 3. Remove duplicates but keep the last occurrence

# %%
# Keeps the most recent occurrence instead of first
df = df.drop_duplicates(keep='last')

# %% [markdown]
# ### 4. Remove duplicates but keep none (Drop all duplicates)

# %%
# Drops all rows that have duplicates (no first ot last kept)
df = df[df.duplicated(keep=False) == False]

# %% [markdown]
# ### 5. Remove duplicates from a specific row (Row-wise unique values)

# %%
# index of the row to modify
row_idx = 2

# removes duplicates within the row while keeping the order
df.iloc[row_idx] = list(dict.fromkeys(df.iloc[row_idx]))

# %% [markdown]
# ### 6. Remove Duplicate values in a specific column

# %%
# Removes duplicates from a single column, but keeps the original DataFrame shape (NaN replaces removes values).
df['remarks'] = df['remarks'].drop_duplicates()

# %% [markdown]
# ### 7. Remove duplicate rows with a condition (keep highest ot lowest value)

# %%
# keeps only the row where value is highest for each id.
# if you have a DataFrame with duplicate IDs but want to keep the row with the highest value in another column:
# df = df.sort_values('value', ascending=False).drop_duplicates(subset=['id'], keep='first')

# %% [markdown]
# ### 8. Remove duplicates using .duplicated()

# %%
# find duplicates without dropping:
df[df.duplicated()]

# find non-duplicate rows:
df[~df.duplicated()]
# Out:
#              timestamp   id     name   age   salary department     location
# 0  2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1  2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2  2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 4  2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing          NaN
# 5  2024-02-23 10:19:10  105  Michael  35.0      NaN    Finance        Miami
# 6  2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 7  2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 8  2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 10 2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#       status  score    remarks
# 0     Active   85.0       Good
# 1     Active   90.0  Excellent
# 2   Inactive    NaN        NaN
# 4     Active   75.0    Average
# 5   Inactive   88.0        NaN
# 6     Active   95.0        NaN
# 7     Active    NaN        NaN
# 8     Active   92.0  Very Good
# 10  Inactive   80.0        NaN

# %% [markdown]
# ### 9. Remove duplicates while resetting index

# %%
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#             timestamp   id     name   age   salary department     location
# 0 2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1 2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2 2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 3 2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing          NaN
# 4 2024-02-23 10:19:10  105  Michael  35.0      NaN    Finance        Miami
# 5 2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 6 2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 7 2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 8 2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#      status  score    remarks
# 0    Active   85.0       Good
# 1    Active   90.0  Excellent
# 2  Inactive    NaN        NaN
# 3    Active   75.0    Average
# 4  Inactive   88.0        NaN
# 5    Active   95.0        NaN
# 6    Active    NaN        NaN
# 7    Active   92.0  Very Good
# 8  Inactive   80.0        NaN

# %% [markdown]
# ### 10. Given a DataFrame with duplicate timestamps, keep only the latest entry

# %%
df = df.sort_values(by='timestamp').drop_duplicates(subset='id', keep='last')

doc = """
        1. df.sort_values(by='timestamp')
                a. Sorts the DataFrame by the 'timestamp' column in ascending order (oldest to newest).
                b. Ensures that the latest timestamp appears last for each id.

        2. .drop_duplicates(subset='id', keep='last')
                a. Removes duplicate rows based on the 'id' column.
                b. keep='last' -> keeps the last occurrence (i.e., the most recent timestamp for each id).
    """

df
# Out:
#             timestamp   id     name   age   salary department     location
# 0 2024-02-23 10:15:30  101     John  25.0  50000.0      Sales     New York  \
# 1 2024-02-23 10:16:45  102     Anna  30.0  60000.0         HR      Chicago
# 2 2024-02-23 10:17:00  103    James   NaN  55000.0         IT  Los Angeles
# 3 2024-02-23 10:18:20  104    Maria  28.0  52000.0  Marketing          NaN
# 4 2024-02-23 10:19:10  105  Michael  35.0      NaN    Finance        Miami
# 5 2024-02-23 10:20:05  106   Sophia  40.0  70000.0         HR      Chicago
# 6 2024-02-23 10:21:30  107     Liam  27.0  48000.0         IT     New York
# 7 2024-02-23 10:22:10  108     Emma   NaN  65000.0      Sales  Los Angeles
# 8 2024-02-23 10:23:50  109  William  32.0  58000.0  Marketing      Chicago
#
#      status  score    remarks
# 0    Active   85.0       Good
# 1    Active   90.0  Excellent
# 2  Inactive    NaN        NaN
# 3    Active   75.0    Average
# 4  Inactive   88.0        NaN
# 5    Active   95.0        NaN
# 6    Active    NaN        NaN
# 7    Active   92.0  Very Good
# 8  Inactive   80.0        NaN
